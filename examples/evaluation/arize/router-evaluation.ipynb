# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import phoenix as px
import os
import json
from tqdm import tqdm
from phoenix.evals import (
    TOOL_CALLING_PROMPT_TEMPLATE, 
    llm_classify,
    OpenAIModel
)
from phoenix.trace import SpanEvaluations
from phoenix.trace.dsl import SpanQuery
from openinference.instrumentation import suppress_tracing

import nest_asyncio
nest_asyncio.apply()

# %%
print(TOOL_CALLING_PROMPT_TEMPLATE)
# Out:
# You are an evaluation assistant evaluating questions and tool calls to
# determine whether the tool called would answer the question. The tool
# calls have been generated by a separate agent, and chosen from the list of
# tools provided below. It is your job to decide whether that agent chose
# the right tool to call.
#
#     [BEGIN DATA]
#     ************
#     [Question]: {question}
#     ************
#     [Tool Called]: {tool_call}
#     [END DATA]
#
# Your response must be single word, either "correct" or "incorrect",
# and should not contain any text or characters aside from that word.
# "incorrect" means that the chosen tool would not answer the question,
# the tool includes information that is not presented in the question,
# or that the tool signature includes parameter values that don't match
# the formats specified in the tool signatures below.
#
# "correct" means the correct tool call was chosen, the correct parameters
# ...

# %%
from router_evals import agent_questions
from experiment import start_main_span

print(agent_questions)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from router_evals import agent_questions
#       2 from experiment import start_main_span
#       4 print(agent_questiona)
#
# ImportError: cannot import name 'agent_questions' from 'router_evals' (C:\Users\Admin\Desktop\TeachingAssistant\project\Teaching-Assistant\examples\evaluation\arize\router_evals.py)

# %%
import os 
print(os.getcwd())
import sys 
sys.path.append("./example_agent")
# Out:
# C:\Users\Admin\Desktop\TeachingAssistant\project\Teaching-Assistant\examples\evaluation\arize

# %%
from experiment import start_main_span
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from experiment import start_main_span
#
# File ~\Desktop\TeachingAssistant\project\Teaching-Assistant\examples\evaluation\arize\experiment.py:1
# ----> 1 from example_agent.ExampleAgent import ExampleAgent
#       2 from examples.evaluation.arize.example_agent.setup_tracing import tracer
#       3 from utils import  get_openai_api_key
#
# File ~\Desktop\TeachingAssistant\project\Teaching-Assistant\examples\evaluation\arize\example_agent\ExampleAgent.py:1
# ----> 1 from router import handle_tool_calls
#       2 from external_tools import tools_schema
#       3 from openai import OpenAI
#
# File ~\Desktop\TeachingAssistant\project\Teaching-Assistant\examples\evaluation\arize\./example_agent\router.py:1
# ----> 1 from external_tools import tool_implementations
#       2 import json
# ...
